# %%
from collections import OrderedDict as OD
from pathlib import Path
import sys

import jsonpickle
import jsonpickle.ext.numpy as jsonpickle_numpy
from matplotlib import pyplot as plt
import numpy as np
import scipy as sp

jsonpickle_numpy.register_handlers()

# %%
# 10 clients, balanced adult: y axis=acc, logl, x=eps in [.5,1]

colours = plt.rcParams['axes.prop_cycle'].by_key()['color']

all_eps = np.array((.5,1)) # list of eps to plot

plot_groups_bal = OD()
plot_groups_bal['DP optimisation'] = []
plot_groups_bal['local avg'] = []
plot_groups_bal['local avg sec'] = []
plot_groups_bal['virtual'] = []
#plot_groups_bal['virtual sec'] = []
#plot_groups['baselines'] = []

# data bal (.75,.95)
plot_groups_unbal1 = OD()
plot_groups_unbal1['DP optimisation'] = []
plot_groups_unbal1['local avg'] = []
plot_groups_unbal1['local avg sec'] = []
plot_groups_unbal1['virtual'] = []
#plot_groups_unbal1['virtual sec'] = []
#plot_groups_unbal1['baselines'] = []

# data bal (.7,-3)
plot_groups_unbal2 = OD()
plot_groups_unbal2['DP optimisation'] = []
plot_groups_unbal2['local avg'] = []
plot_groups_unbal2['local avg sec'] = []
plot_groups_unbal2['virtual'] = []
#plot_groups_unbal2['virtual sec'] = []
#plot_groups_unbal2['baselines'] = []

# set baselines


# dpsgd eps 1
plot_groups_bal['DP optimisation'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_dpsgd_10clients_5seeds_eps1_runs/',
                    'run_id' : '9',
                    'eps':1,
                    'delta': 1e-5,
                    'colour':colours[0],})

plot_groups_unbal1['DP optimisation'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_dpsgd_10clients_5seeds_eps1_runs/',
                    'run_id' : '2',
                    'eps':1,
                    'delta': 1e-5,
                    'colour':colours[0],})
plot_groups_unbal2['DP optimisation'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_dpsgd_10clients_5seeds_eps1_runs/',
                    'run_id' : '8',
                    'eps':1,
                    'delta': 1e-5,
                    'colour':colours[0],})

# dpsgd eps .5
plot_groups_bal['DP optimisation'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_dpsgd_10clients_5seeds_eps05_runs/',
                    'run_id' : '9',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[0],})

plot_groups_unbal1['DP optimisation'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_dpsgd_10clients_5seeds_eps05_runs/',
                    'run_id' : '2',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[0],})

plot_groups_unbal2['DP optimisation'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_dpsgd_10clients_5seeds_eps05_runs/',
                    'run_id' : '3',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[0],})

#"""
# lfa eps 1
plot_groups_bal['local avg'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_10clients_5seeds_eps1_runs/',
                    'run_id' : '1',
                    'eps':1,
                    'delta': 1e-5,
                    'colour':colours[1],})
plot_groups_unbal1['local avg'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_10clients_5seeds_eps1_runs/',
                    'run_id' : '3',
                    'eps':1,
                    'delta': 1e-5,
                    'colour':colours[1],})
plot_groups_unbal2['local avg'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_10clients_5seeds_eps1_runs/',
                    'run_id' : '4',
                    'eps':1,
                    'delta': 1e-5,
                    'colour':colours[1],})



# lfa eps .5
plot_groups_bal['local avg'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_10clients_5seeds_eps05_runs/',
                    'run_id' : '9',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[1],})
plot_groups_unbal1['local avg'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_10clients_5seeds_eps05_runs/',
                    'run_id' : '12',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[1],})
plot_groups_unbal2['local avg'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_10clients_5seeds_eps05_runs/',
                    'run_id' : '13',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[1],})



# lfa sec eps 1
#"""
plot_groups_bal['local avg sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_10clients_5seeds_eps1_sec_runs/',
                    'run_id' : '2',
                    'eps':1,
                    'delta': 1e-5,
                    'colour':colours[1],})
plot_groups_unbal1['local avg sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_10clients_5seeds_eps1_sec_runs/',
                    'run_id' : '9',
                    'eps':1,
                    'delta': 1e-5,
                    'colour':colours[1],})
plot_groups_unbal2['local avg sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_10clients_5seeds_eps1_sec_runs/',
                    'run_id' : '8',
                    'eps':1,
                    'delta': 1e-5,
                    'colour':colours[1],})


# lfa sec eps .5
plot_groups_bal['local avg sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_10clients_5seeds_eps05_sec_runs/',
                    'run_id' : '4',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[1],})
plot_groups_unbal1['local avg sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_10clients_5seeds_eps05_sec_runs/',
                    'run_id' : '9',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[1],})
plot_groups_unbal2['local avg sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_10clients_5seeds_eps05_sec_runs/',
                    'run_id' : '8',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[1],})

#"""


#######
#"""
# virtual clients eps 1
plot_groups_bal['virtual'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_10clients_5seeds_eps1_runs/',
                    'run_id' : '2',
                    'eps':1,
                    'delta': 1e-5,
                    'colour':colours[2],})
plot_groups_unbal1['virtual'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_10clients_5seeds_eps1_runs/',
                    'run_id' : '3',
                    'eps':1,
                    'delta': 1e-5,
                    'colour':colours[2],})
plot_groups_unbal2['virtual'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_10clients_5seeds_eps1_runs/',
                    'run_id' : '4',
                    'eps':1,
                    'delta': 1e-5,
                    'colour':colours[2],})


# virtual clients eps .5
plot_groups_bal['virtual'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_10clients_5seeds_eps05_runs/',
                    'run_id' : '2',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[2],})
plot_groups_unbal1['virtual'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_10clients_5seeds_eps05_runs/',
                    'run_id' : '8',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[2],})
plot_groups_unbal2['virtual'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_10clients_5seeds_eps05_runs/',
                    'run_id' : '3',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[2],})

"""
# virtual clients sec eps 1
plot_groups_bal['virtual sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_10clients_5seeds_eps1_sec_runs/',
                    'run_id' : '3',
                    'eps':1,
                    'delta': 1e-5,
                    'colour':colours[2],})
plot_groups_unbal1['virtual sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_10clients_5seeds_eps1_sec_runs/',
                    'run_id' : '6',
                    'eps':1,
                    'delta': 1e-5,
                    'colour':colours[2],})
plot_groups_unbal2['virtual sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_10clients_5seeds_eps1_sec_runs/',
                    'run_id' : '8',
                    'eps':1,
                    'delta': 1e-5,
                    'colour':colours[2],})

# virtual clients sec eps .5
plot_groups_bal['virtual sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_10clients_5seeds_eps05_sec_runs/',
                    'run_id' : '1',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[2],})
plot_groups_unbal1['virtual sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_10clients_5seeds_eps05_sec_runs/',
                    'run_id' : '?puuttuu',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[2],})
plot_groups_unbal2['virtual sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_10clients_5seeds_eps05_sec_runs/',
                    'run_id' : '?puuttuu',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[2],})
#"""
#
# Out:
# "\n# virtual clients sec eps 1\nplot_groups_bal['virtual sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_10clients_5seeds_eps1_sec_runs/',\n                    'run_id' : '3',\n                    'eps':1,\n                    'delta': 1e-5,\n                    'colour':colours[2],})\nplot_groups_unbal1['virtual sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_10clients_5seeds_eps1_sec_runs/',\n                    'run_id' : '6',\n                    'eps':1,\n                    'delta': 1e-5,\n                    'colour':colours[2],})\nplot_groups_unbal2['virtual sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_10clients_5seeds_eps1_sec_runs/',\n                    'run_id' : '8',\n                    'eps':1,\n                    'delta': 1e-5,\n                    'colour':colours[2],})\n\n# virtual clients sec eps .5\nplot
# ...

# %%
# plot 10 clients, bal adult data, log.regr
all_res, all_baselines = reset_all_res()
read_results_for_groups(all_res,plot_groups_bal, dataset_name='adult')
plot_figure(all_res, plot_groups_bal, suptitle='Adult data, 10 clients, balanced split',measures=['best_acc','best_logl'],
            y_names=['Accuracy', 'Logl'],
            filename=None
            #filename='figs/adult_10clients_bal_with_sec.pdf'
            #filename='figs/adult_10clients_bal.pdf'
            #filename='figs/adult_10clients_bal_only_sec.pdf'
           )

# %%
# plot 10 clients, unbal1 adult data, log.regr
reset_all_res()
read_results_for_groups(all_res,plot_groups_unbal1, dataset_name='adult')
plot_figure(all_res,plot_groups_unbal1, suptitle='Adult data, 10 clients, unbalanced split 1',measures=['best_acc','best_logl'],
            y_names=['Accuracy', 'Logl'],
            filename=None
            #filename='figs/adult_10clients_bal_with_sec.pdf'
            #filename='figs/adult_10clients_bal.pdf'
            #filename='figs/adult_10clients_bal_only_sec.pdf'
           )

# %%
# plot 10 clients, unbal2 adult data, log.regr
reset_all_res()
read_results_for_groups(all_res,plot_groups_unbal1, dataset_name='adult')
plot_figure(all_res,plot_groups_unbal2, suptitle='Adult data, 10 clients, unbalanced split 2',measures=['best_acc','best_logl'],
            y_names=['Accuracy', 'Logl'],
            filename=None
            #filename='figs/adult_10clients_bal_with_sec.pdf'
            #filename='figs/adult_10clients_bal.pdf'
            #filename='figs/adult_10clients_bal_only_sec.pdf'
           )

# %%
# 200 clients, balanced adult: y axis=acc, logl, x=eps in [.5,1]

colours = plt.rcParams['axes.prop_cycle'].by_key()['color']

all_eps = np.array((.3,.5)) # list of eps to plot

plot_groups_bal = OD()
plot_groups_bal['DP optimisation'] = []
plot_groups_bal['local avg sec'] = []
plot_groups_bal['virtual sec'] = []
plot_groups_unbal1 = OD()
plot_groups_unbal1['DP optimisation'] = []
plot_groups_unbal1['local avg sec'] = []
plot_groups_unbal1['virtual sec'] = []
plot_groups_unbal2 = OD()
plot_groups_unbal2['DP optimisation'] = []
plot_groups_unbal2['local avg sec'] = []
plot_groups_unbal2['virtual sec'] = []

#plot_groups['baselines'] = []

# dpsgd eps .3
plot_groups_bal['DP optimisation'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_dpsgd_200clients_5seeds_eps03_runs/',
                    'run_id' : '9',
                    'eps':.3,
                    'delta': 1e-5,
                    'colour':colours[0],
                        })
plot_groups_unbal1['DP optimisation'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_dpsgd_200clients_5seeds_eps03_runs/',
                    'run_id' : '8',
                    'eps':.3,
                    'delta': 1e-5,
                    'colour':colours[0],
                        })
plot_groups_unbal2['DP optimisation'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_dpsgd_200clients_5seeds_eps03_runs/',
                    'run_id' : '2',
                    'eps':.3,
                    'delta': 1e-5,
                    'colour':colours[0],
                        })

# dpsgd eps .5
plot_groups_bal['DP optimisation'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_dpsgd_200clients_5seeds_eps05_runs/',
                    'run_id' : '7',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[0],
                        })
plot_groups_unbal1['DP optimisation'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_dpsgd_200clients_5seeds_eps05_runs/',
                    'run_id' : '11',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[0],
                        })
plot_groups_unbal2['DP optimisation'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_dpsgd_200clients_5seeds_eps05_runs/',
                    'run_id' : '13',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[0],
                        })

# lfa sec eps .3
plot_groups_bal['local avg sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_200clients_5seeds_eps03_sec_runs/',
                    'run_id' : '3',
                    'eps':.3,
                    'delta': 1e-5,
                    'colour':colours[1],
                        })
plot_groups_unbal1['local avg sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_200clients_5seeds_eps03_sec_runs/',
                    'run_id' : '14',
                    'eps':.3,
                    'delta': 1e-5,
                    'colour':colours[1],
                        })
plot_groups_unbal2['local avg sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_200clients_5seeds_eps03_sec_runs/',
                    'run_id' : '12',
                    'eps':.3,
                    'delta': 1e-5,
                    'colour':colours[1],
                        })

# lfa sec eps .5
plot_groups_bal['local avg sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_200clients_5seeds_eps05_sec_runs/',
                    'run_id' : '1',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[1],
                        })
plot_groups_unbal1['local avg sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_200clients_5seeds_eps05_sec_runs/',
                    'run_id' : '9',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[1],
                        })
plot_groups_unbal2['local avg sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_200clients_5seeds_eps05_sec_runs/',
                    'run_id' : '17',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[1],
                        })

# virtual clients sec eps .3
plot_groups_bal['virtual sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_200clients_5seeds_eps03_sec_runs/',
                    'run_id' : '15',
                    'eps':.3,
                    'delta': 1e-5,
                    'colour':colours[2],
                        })
plot_groups_unbal1['virtual sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_200clients_5seeds_eps03_sec_runs/',
                    'run_id' : '7',
                    'eps':.3,
                    'delta': 1e-5,
                    'colour':colours[2],
                        })
plot_groups_unbal2['virtual sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_200clients_5seeds_eps03_sec_runs/',
                    'run_id' : '8',
                    'eps':.3,
                    'delta': 1e-5,
                    'colour':colours[2],
                        })
# unbal: 1,7; 8

# virtual clients sec eps .5
plot_groups_bal['virtual sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_200clients_5seeds_eps05_sec_runs/',
                    'run_id' : '3',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[2],
                        })
plot_groups_unbal1['virtual sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_200clients_5seeds_eps05_sec_runs/',
                    'run_id' : '13',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[2],
                        })
plot_groups_unbal2['virtual sec'].append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_200clients_5seeds_eps05_sec_runs/',
                    'run_id' : '12',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[2],
                        })
# idt=13;12 vakaammat; 10;11,5 hajoaa

# %%
# plot 200 clients, bal adult data, log.regr
all_res, all_baselines = reset_all_res()
read_results_for_groups(all_res, plot_groups_bal, dataset_name='adult')
plot_figure(all_res, plot_groups_bal, suptitle='Log.regr. with Adult, 200 clients, balanced split',measures=['best_acc_at_logl','best_logl'],
            y_names=['Accuracy', 'Logl'],
            filename=None,
            #filename='figs/adult_200clients_bal_eps.pdf',
            legend_fontsize = 14,
           )
# Out:
# run 9
# run 7
# run 3
# run 1
# run 15
# run 3
# Saved figure into figs/adult_200clients_bal_eps.pdf

# %%
# plot 200 clients, unbal1 adult data, log.regr
all_res, all_baselines = reset_all_res()
read_results_for_groups(all_res, plot_groups_unbal1, dataset_name='adult')
plot_figure(all_res, plot_groups_unbal1, suptitle='Log.regr. with Adult, 200 clients, unbalanced split 1',measures=['best_acc_at_logl','best_logl'],
            y_names=['Accuracy', 'Logl'],
            filename=None,
            #filename='figs/adult_200clients_unbal1_eps.pdf',
            legend_fontsize = 14,
           )
# Out:
# run 8
# run 11
# run 14
# run 9
# run 7
# run 13
# Saved figure into figs/adult_200clients_unbal1_eps.pdf

# %%
# plot 200 clients, unbal2 adult data, log.regr
all_res, all_baselines = reset_all_res()
read_results_for_groups(all_res, plot_groups_unbal2, dataset_name='adult')
plot_figure(all_res, plot_groups_unbal2, suptitle='Log.regr. with Adult, 200 clients, unbalanced split 2',measures=['best_acc_at_logl','best_logl'],
            y_names=['Accuracy', 'Logl'],
            filename=None,
            #filename='figs/adult_200clients_unbal2_eps.pdf',
            legend_fontsize = 14,
           )
# Out:
# run 2
# run 13
# run 12
# run 17
# run 8
# run 12
# Saved figure into figs/adult_200clients_unbal2_eps.pdf

# %%
for k in all_res:
    print(k)
#print(all_res)
print(all_res['validation_res']['2_0']['best_acc_at_logl'])
print(all_res['validation_res']['2_1']['best_acc_at_logl'])
# Out:
# config
# validation_res
# [0.84013759 0.84103845 0.83890914 0.83542852 0.83993284]
# [0.84087466 0.84198026 0.8472626  0.84075181 0.84013759]

# %%
print(plot_groups['virtual sec'][-1])
# Out:
# {'folder': '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_200clients_5seeds_eps05_sec_runs/', 'run_id': '1', 'eps': 0.5, 'delta': 1e-05, 'bal': 'bal'}

# %%
print(all_res['validation_res']['2_0']['logl'])
# Out:
# [[-0.52194327 -0.50682384 -0.53105444 -0.52445531 -0.52417588]
#  [-0.4575052  -0.4633536  -0.45988384 -0.45350596 -0.4668085 ]
#  [-0.42689168 -0.43446264 -0.43492621 -0.42886433 -0.43865263]
#  [-0.4003703  -0.41094279 -0.41753671 -0.41630951 -0.42985433]
#  [-0.38475543 -0.40121147 -0.40446991 -0.40226594 -0.40306079]
#  [-0.38172814 -0.39095047 -0.39029354 -0.39013901 -0.38784155]
#  [-0.37797892 -0.3841145  -0.38107315 -0.3836838  -0.38092807]
#  [-0.37239259 -0.37822947 -0.37686804 -0.3768664  -0.37292156]
#  [-0.36744913 -0.37288699 -0.37273756 -0.37913835 -0.36445218]
#  [-0.36465102 -0.36902854 -0.37324929 -0.37259507 -0.3617954 ]
#  [-0.36138862 -0.36641648 -0.36916754 -0.3680205  -0.3612881 ]
#  [-0.35964799 -0.36503011 -0.36350152 -0.36401325 -0.35954607]
#  [-0.35683927 -0.36233953 -0.36062756 -0.36152738 -0.35819045]
#  [-0.35340604 -0.36117464 -0.35648617 -0.35864109 -0.3584969 ]
#  [-0.35308424 -0.35763386 -0.35645047 -0.35571501 -0.35674787]]

# %%
for k in all_res['config']:
    print(k)
# Out:
# 0_0
# 0_1
# 1_0
# 1_1
# 2_0
# 2_1

# %%
# define helper funs

def plot_figure(all_res,plot_groups, suptitle='', measures=['best_acc_at_logl','best_logl'],y_names=['Accuracy', 'Logl'], filename=None, legend_fontsize=14):
    fig, axs = plt.subplots(2,1, figsize=(8,10))
    for i_group, k in enumerate(plot_groups):
        y = np.zeros((2,2,len(plot_groups[k])))
        for i_run,params in enumerate(plot_groups[k]):
            assert not np.any(np.isnan(all_res['validation_res'][str(i_group)+'_'+str(i_run)][measures[0]]))
            assert not np.any(np.isnan(all_res['validation_res'][str(i_group)+'_'+str(i_run)][measures[1]]))
            
            #print(all_res['validation_res'][str(i_group)+'_'+str(i_run)]['best_acc'].mean(-1))
            y[0,0,plot_groups[k][i_run]['eps'] == all_eps] = all_res['validation_res'][str(i_group)+'_'+str(i_run)][measures[0]].mean(-1)
            #y[0,1,i_run] = np.nanstd( all_res['validation_res'][str(i_group)+'_'+str(i_run)][measures[0]],-1)
            y[0,1,i_run] = all_res['validation_res'][str(i_group)+'_'+str(i_run)][measures[0]].std(-1)
        
            y[1,0,plot_groups[k][i_run]['eps'] == all_eps] = all_res['validation_res'][str(i_group)+'_'+str(i_run)][measures[1]].mean(-1)
            #y[1,1,i_run] = np.nanstd(all_res['validation_res'][str(i_group)+'_'+str(i_run)][measures[1]],-1)
            y[1,1,i_run] = all_res['validation_res'][str(i_group)+'_'+str(i_run)][measures[1]].std(-1)
        
        # note: take colour from last instance of the group
        axs[0].errorbar(all_eps, y[0,0,:],yerr=y[0,1,:]/np.sqrt(5), marker='*', label=k, color=params['colour'])
        axs[1].errorbar(all_eps, y[1,0,:],yerr=y[1,1,:]/np.sqrt(5), marker='*', label=k, color=params['colour'])
    for i in range(2):
        axs[i].grid()
        axs[i].legend(fontsize=legend_fontsize)
        axs[i].set_xlabel('$\epsilon$', fontsize=legend_fontsize+1)
    axs[0].set_ylabel(y_names[0], fontsize=legend_fontsize+1)
    axs[1].set_ylabel(y_names[1], fontsize=legend_fontsize+1)
    plt.suptitle(suptitle, fontsize=legend_fontsize+2)
    plt.tight_layout()
    if filename is None:
        plt.show()
    else:
        plt.savefig(filename)
        print(f'Saved figure into {filename}')
#

# read results
def read_results_for_groups(all_res,plot_groups, dataset_name='adult'):
    for i_group, k in enumerate(plot_groups):
        for i_run, params in enumerate(plot_groups[k]):
            get_results(all_res,plot_id=str(i_group)+'_'+str(i_run),run_id=params['run_id'], main_folder=params['folder'], dataset_name=dataset_name)

def reset_all_res():
    all_res = OD()
    all_res['config'] = OD()
    all_res['validation_res'] = OD()
    all_baselines = OD()
    all_baselines['config'] = OD()
    all_baselines['validation_res'] = OD()
    return all_res, all_baselines

def get_results(all_res,plot_id,run_id, main_folder, dataset_name):
    """ run_id (str): run id in main folder
        plot_id (str): id for plotting
    """
    print(f'run {run_id}')
    filename = main_folder + run_id + '/config.json'
    #print(f'trying {filename}')
    tmp = read_config(filename, failed_runs=[])
    #if i_run in failed_runs:
    #    continue
    all_res['config'][plot_id] = tmp[0]

    # try opening sacred records, if missing open manual bck instead
    #filename = main_folder + run_id + '/info.json'
    filename = ''
    filename_bck = main_folder + run_id + '/info_bck.json'
    apu = read_results(filename, filename_bck)

    #print(apu['validation_res_seed0']['logl'].shape)
    #sys.exit()

    #for k in apu:
    #    print(k)
    #sys.exit()
    
    # format results for plotting
    client_measures = ['elbo','kl','logl']
    format_results(apu, plot_id, client_measures, all_res, dataset_name)

#
def read_config(filename, failed_runs):
    try:
        with open(filename, 'r') as f:
            apu = f.read()
    except FileNotFoundError as err:
        print(f"Can't open file {filename}! Skipping")
        failed_runs.append(i_run)
        return None
    apu = jsonpickle.unpickler.decode(apu)
    #print(apu)
    return apu, failed_runs


def read_results(filename, filename_bck):
    try:
        with open(filename, 'r') as f:
            apu = f.read()
        try:
            apu = jsonpickle.unpickler.decode(apu)
        except:
            print(f'error in JSON decoding in run {filename}')
            with open(filename, 'r') as f:
                apu = f.read()
            print('results from file: {}\n{}'.format(filename,apu))
            sys.exit()
    except FileNotFoundError as err:
        import json
        with open(filename_bck, 'r') as f:
            apu = f.read()
            apu = json.loads(apu)
        try:
            #apu = jsonpickle.unpickler.decode(apu)
            #print(apu)
            apu = jsonpickle.decode(apu, keys=True)
            #print(apu)
            #print('at bck decode')
        except:
            print(f'error in JSON decoding in {filename_bck}')
            #with open(filename, 'r') as f:
            #    apu = f.read()
            #print('results from file: {}\n{}'.format(filename,apu))
            sys.exit()
    return apu

def format_results(apu, run_id, client_measures, all_res, dataset_name):

    '''
    all_res['client_train_res'][run_id] = {}

    for k in client_measures:
        all_res['client_train_res'][run_id][k] = np.zeros((
            all_res['config'][run_id]['clients'],  
            all_res['config'][run_id]['n_global_updates'],  
            all_res['config'][run_id]['n_steps'],  
            all_res['config'][run_id]['n_rng_seeds']
            ))
    '''
    measures = ['acc','logl']
    posneg_measures = ['avg_prec_score','balanced_acc','f1_score']
    
    #all_res['train_res'][run_id] = {}
    all_res['validation_res'][run_id] = {}
    for k in (measures+posneg_measures):
        #all_res['train_res'][run_id][k] = np.zeros((
        #    all_res['config'][run_id]['n_global_updates'],  
        #    all_res['config'][run_id]['n_rng_seeds']
        #    ))
        all_res['validation_res'][run_id][k] = np.zeros((
            all_res['config'][run_id]['n_global_updates'],  
            all_res['config'][run_id]['n_rng_seeds']
            ))
        #all_res['train_res'][run_id]['best_'+k] = np.zeros((
        #    all_res['config'][run_id]['n_rng_seeds']
        #    ))
        all_res['validation_res'][run_id]['best_'+k] = np.zeros((
            all_res['config'][run_id]['n_rng_seeds']
            ))
    all_res['validation_res'][run_id]['best_acc_at_logl'] = np.zeros((
            all_res['config'][run_id]['n_rng_seeds']
            ))

    # does this work with sampling=seq?
    if dataset_name != 'mnist':
        # for plotting ROC curve for max logl global update, one for each seed
        all_res['validation_res'][run_id]['TPR'] = np.zeros((
            all_res['config'][run_id]['n_rng_seeds'],
            apu['validation_res_seed0']['posneg'][0]['n_points']
            ))
        all_res['validation_res'][run_id]['TNR'] = np.zeros((
            all_res['config'][run_id]['n_rng_seeds'],
            apu['validation_res_seed0']['posneg'][0]['n_points']
            ))
        all_res['validation_res'][run_id]['ROC_thresholds'] = np.linspace(0,1,apu['validation_res_seed0']['posneg'][0]['n_points'])


    for i_seed in range(all_res['config'][run_id]['n_rng_seeds']):
        # logl, elbo, kl
        '''
        if i_seed == 0:
            for k in apu[f'validation_res_seed{i_seed}']:
                print(k)
            print(apu[f'validation_res_seed{i_seed}']['acc'].shape )
            print(apu[f'client_train_res_seed{i_seed}']['logl'].shape )
        #'''
        #sys.exit()
        #for k in client_measures:
        #    try:
        #        all_res['client_train_res'][run_id][k][:,:,:,i_seed] = apu[f'client_train_res_seed{i_seed}'][k]
        #    except KeyError as err:
        #        print(f'KeyError in run {i_run} (=folder)')
        #        print(f'got\n{apu}')
        #        print("config: batch_size={}, jobid={}".format(all_res['config'][run_id]['batch_size'], all_res['config'][run_id]['job_id'] ))
        #        raise err

        for k in measures:
            #all_res['train_res'][run_id][k][:,i_seed] = apu[f'train_res_seed{i_seed}'][k]
            all_res['validation_res'][run_id][k][:,i_seed] = apu[f'validation_res_seed{i_seed}'][k]

            #all_res['train_res'][run_id]['best_'+k][i_seed] = np.amax(all_res['train_res'][run_id][k][:,i_seed])
            all_res['validation_res'][run_id]['best_'+k][i_seed] = np.amax(all_res['validation_res'][run_id][k][:,i_seed])

        # calculate true positive and true negative rates at global update with best logl
        #print( all_res['validation_res'][run_id]['logl'][:,i_seed] )
        best_global_logl = np.argmax( all_res['validation_res'][run_id]['logl'][:,i_seed] )
        #print(all_res['validation_res'][run_id]['logl'][:,i_seed][best_global_logl])
        #print(all_res['validation_res'][run_id]['best_logl'][i_seed])
        # all_res['validation_res'][run_id] = {}
        #print(f'best global logl: {best_global_logl}')
        #sys.exit()
        # calculate best acc at best logl
        all_res['validation_res'][run_id]['best_acc_at_logl'][i_seed] = all_res['validation_res'][run_id]['acc'][best_global_logl,i_seed]

        if dataset_name != 'mnist':
            try:
                all_res['validation_res'][run_id]['TPR'][i_seed,:] = apu[f"validation_res_seed{i_seed}"]['posneg'][best_global_logl]['TP']/( apu[f"validation_res_seed{i_seed}"]['posneg'][best_global_logl]['TP'] + apu[f"validation_res_seed{i_seed}"]['posneg'][best_global_logl]['FN'])

                all_res['validation_res'][run_id]['TNR'][i_seed,:] = apu[f"validation_res_seed{i_seed}"]['posneg'][best_global_logl]['TN']/( apu[f"validation_res_seed{i_seed}"]['posneg'][best_global_logl]['TN'] + apu[f"validation_res_seed{i_seed}"]['posneg'][best_global_logl]['FP'])
                # posneg = list of posneg dicts with len=n_global_updates
                # NOTE: need to check format when n_seeds > 1
                for i_global in range(all_res['config'][run_id]['n_global_updates']):
                    for k in posneg_measures:
                        #print(apu[f"validation_res_seed0"]['posneg'][i_global][k])
                        #all_res['train_res'][run_id][k][i_global,i_seed] = apu[f"train_res_seed{i_seed}"]['posneg'][i_global][k]
                        all_res['validation_res'][run_id][k][i_global,i_seed] = apu[f"validation_res_seed{i_seed}"]['posneg'][i_global][k]
                        #print(len(apu[f"validation_res_seed0"]['posneg']),len(apu[f"train_res_seed0"]['posneg'] ))
                        #sys.exit()

                for k in posneg_measures:
                    #all_res['train_res'][run_id]['best_'+k][i_seed] = np.amax(all_res['train_res'][run_id][k][:,i_seed])
                    all_res['validation_res'][run_id]['best_'+k][i_seed] = np.amax(all_res['validation_res'][run_id][k][:,i_seed])
            except:
                pass
