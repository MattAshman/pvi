# %%
from collections import OrderedDict as OD
from pathlib import Path
import sys

import jsonpickle
import jsonpickle.ext.numpy as jsonpickle_numpy
from matplotlib import pyplot as plt
import numpy as np
import scipy as sp

jsonpickle_numpy.register_handlers()

# %% [markdown]
# ### Bal MIMIC runs, 10 clients

# %%
# 10 clients, balanced mimic: y axis=acc, logl
plot_group_bal = []
plot_group_unbal1 = []
plot_group_unbal2 = []

colours = plt.rcParams['axes.prop_cycle'].by_key()['color']

plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/mimic_bal_dpsgd_10clients_5seeds_eps1_runs/',
                    'name' : 'DP optimisation',
                    'run_id' : '1', # run number in main folder
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[0],})

plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/mimic_bal_dpsgd_10clients_5seeds_eps1_runs/',
                    'name' : 'DP optimisation',
                    'run_id' : '5',
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[0],})

plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/mimic_bal_dpsgd_10clients_5seeds_eps1_runs/',
                    'name' : 'DP optimisation',
                    'run_id' : '3',
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[0],})



plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/mimic_bal_lfa_10clients_5seeds_eps1_runs/',
                    'name' : 'local avg',
                    'run_id' : '1', # run number in main folder
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[1],})
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/mimic_bal_lfa_10clients_5seeds_eps1_runs/',
                    'name' : 'local avg',
                    'run_id' : '3',
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[1],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/mimic_bal_lfa_10clients_5seeds_eps1_runs/',
                    'name' : 'local avg',
                    'run_id' : '7',
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[1],})



plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/mimic_bal_lfa_10clients_5seeds_eps1_sec_runs/',
                    'name' : 'local avg, trusted aggr.',
                    'run_id' : '28',
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[1],})
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/mimic_bal_lfa_10clients_5seeds_eps1_sec_runs/',
                    'name' : 'local avg, trusted aggr.',
                    'run_id' : '21',
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[1],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/mimic_bal_lfa_10clients_5seeds_eps1_sec_runs/',
                    'name' : 'local avg, trusted aggr.',
                    'run_id' : '18',
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[1],})


plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/mimic_bal_local_pvi_10clients_5seeds_eps1_runs/',
                    'name' : 'virtual',
                    'run_id' : '18', # run number in main folder
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[2],})
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/mimic_bal_local_pvi_10clients_5seeds_eps1_runs/',
                    'name' : 'virtual',
                    'run_id' : '13', 
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[2],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/mimic_bal_local_pvi_10clients_5seeds_eps1_runs/',
                    'name' : 'virtual',
                    'run_id' : '5', 
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[2],})

plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/mimic_bal_local_pvi_10clients_5seeds_eps1_sec_runs/',
                    'name' : 'virtual, trusted aggr.',
                    'run_id' : '4', 
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[2],})
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/mimic_bal_local_pvi_10clients_5seeds_eps1_sec_runs/',
                    'name' : 'virtual, trusted aggr.',
                    'run_id' : '1', 
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[2],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/mimic_bal_local_pvi_10clients_5seeds_eps1_sec_runs/',
                    'name' : 'virtual, trusted aggr.',
                    'run_id' : '2', 
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[2],})



plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/mimic_bal_bcm_same_10clients_5seeds_eps1_runs/',
                    'name' : 'BCM same',
                    'run_id' : '2', # run number in main folder
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[3],})
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/mimic_bal_bcm_same_10clients_5seeds_eps1_runs/',
                    'name' : 'BCM same',
                    'run_id' : '4',
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[3],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/mimic_bal_bcm_same_10clients_5seeds_eps1_runs/',
                    'name' : 'BCM same',
                    'run_id' : '6',
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[3],})


plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/mimic_bal_bcm_split_10clients_5seeds_eps1_runs/',
                    'name' : 'BCM split',
                    'run_id' : '2', # run number in main folder
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[4],})
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/mimic_bal_bcm_split_10clients_5seeds_eps1_runs/',
                    'name' : 'BCM split',
                    'run_id' : '5',
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[4],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/mimic_bal_bcm_split_10clients_5seeds_eps1_runs/',
                    'name' : 'BCM split',
                    'run_id' : '6',
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[4],})


# for global vi need to have 'clients' directly in dict
plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/mimic_bal_comms_baseline_5seeds_eps1_runs/',
                    'name' : 'global VI, trusted aggr.',
                    'clients' : 10,
                    'run_id' : '1', # run number in main folder
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[5],})
plot_group_unbal1.append(plot_group_bal[-1])
plot_group_unbal2.append(plot_group_bal[-1])

# %% [markdown]
# ### ADULT runs, 10 clients

# %%
# 10 clients, adult: y axis=acc, logl
plot_group_bal = []
plot_group_unbal1 = []
plot_group_unbal2 = []

colours = plt.rcParams['axes.prop_cycle'].by_key()['color']

plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_dpsgd_10clients_5seeds_eps1_runs/',
                    'name' : 'DP optimisation',
                    'run_id' : '9', # run number in main folder
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[0],})

plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_dpsgd_10clients_5seeds_eps1_runs/',
                    'name' : 'DP optimisation',
                    'run_id' : '2',
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[0],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_dpsgd_10clients_5seeds_eps1_runs/',
                    'name' : 'DP optimisation',
                    'run_id' : '8',
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[0],})



plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_10clients_5seeds_eps1_runs/',
                    'name' : 'local avg',
                    'run_id' : '1', # run number in main folder
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[1],})
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_10clients_5seeds_eps1_runs/',
                    'name' : 'local avg',
                    'run_id' : '3',
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[1],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_10clients_5seeds_eps1_runs/',
                    'name' : 'local avg',
                    'run_id' : '4',
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[1],})



plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_10clients_5seeds_eps1_sec_runs/',
                    'name' : 'local avg, trusted aggr.',
                    'run_id' : '2', # run number in main folder
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[1],})
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_10clients_5seeds_eps1_sec_runs/',
                    'name' : 'local avg, trusted aggr.',
                    'run_id' : '11', # run number in main folder
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[1],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_10clients_5seeds_eps1_sec_runs/',
                    'name' : 'local avg, trusted aggr.',
                    'run_id' : '14', # run number in main folder
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[1],})



plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_10clients_5seeds_eps1_runs/',
                    'name' : 'virtual',
                    'run_id' : '2', # run number in main folder
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[2],})
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_10clients_5seeds_eps1_runs/',
                    'name' : 'virtual',
                    'run_id' : '3', 
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[2],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_10clients_5seeds_eps1_runs/',
                    'name' : 'virtual',
                    'run_id' : '4', 
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[2],})

plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_10clients_5seeds_eps1_sec_runs/',
                    'name' : 'virtual, trusted aggr.',
                    'run_id' : '3', # run number in main folder
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[2],})
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_10clients_5seeds_eps1_sec_runs/',
                    'name' : 'virtual, trusted aggr.',
                    'run_id' : '6', # run number in main folder
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[2],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_10clients_5seeds_eps1_sec_runs/',
                    'name' : 'virtual, trusted aggr.',
                    'run_id' : '8', # run number in main folder
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[2],})



plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_bcm_same_10clients_5seeds_eps1_runs/',
                    'name' : 'BCM same',
                    'run_id' : '5', # run number in main folder
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[3],})
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_bcm_same_10clients_5seeds_eps1_runs/',
                    'name' : 'BCM same',
                    'run_id' : '1',
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[3],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_bcm_same_10clients_5seeds_eps1_runs/',
                    'name' : 'BCM same',
                    'run_id' : '7',
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[3],})


plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_bcm_split_10clients_5seeds_eps1_runs/',
                    'name' : 'BCM split',
                    'run_id' : '2', # run number in main folder
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[4],})
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_bcm_split_10clients_5seeds_eps1_runs/',
                    'name' : 'BCM split',
                    'run_id' : '6',
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[4],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_bcm_split_10clients_5seeds_eps1_runs/',
                    'name' : 'BCM split',
                    'run_id' : '7',
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[4],})


# for global vi need to have 'clients' directly in dict
plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_comms_baseline_5seeds_eps1_runs/',
                    'name' : 'global VI, trusted aggr.',
                    'clients' : 10,
                    'run_id' : '1', # run number in main folder
                    'eps': 1,
                    'delta': 1e-5,
                    'colour':colours[5],})
# full trusted aggr comms baseline same for all splits
plot_group_unbal1.append(plot_group_bal[-1])
plot_group_unbal2.append(plot_group_bal[-1])

# %% [markdown]
# ### Adult 1BNN, 10 clients

# %%
# 1BNN runs, adult 10 clients, eps=2

colours = plt.rcParams['axes.prop_cycle'].by_key()['color']

plot_group_bal = []
plot_group_unbal1 = []
plot_group_unbal2 = []

plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_1bnn_dpsgd_10clients_5seeds_eps2_runs/',
                    'name' : 'DP optimization',
                    'run_id' : '9', # run number in main folder
                    'eps': 2,
                    'delta': 1e-5,
                    'colour':colours[0],})

plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_1bnn_dpsgd_10clients_5seeds_eps2_runs/',
                    'name' : 'DP optimization',
                    'run_id' : '3',
                    'eps': 2,
                    'delta': 1e-5,
                    'colour':colours[0],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_1bnn_dpsgd_10clients_5seeds_eps2_runs/',
                    'name' : 'DP optimization',
                    'run_id' : '4',
                    'eps': 2,
                    'delta': 1e-5,
                    'colour':colours[0],})



plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_1bnn_lfa_10clients_5seeds_eps2_runs/',
                    'name' : 'local avg',
                    'run_id' : '1',
                    'eps': 2,
                    'delta': 1e-5,
                    'colour':colours[1],})
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/kale_adult_1bnn_lfa_10clients_5seeds_eps2_runs/',
                    'name' : 'local avg',
                    'run_id' : '2', #
                    'eps': 2,
                    'delta': 1e-5,
                    'colour':colours[1],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/kale_adult_1bnn_lfa_10clients_5seeds_eps2_runs/',
                    'name' : 'local avg',
                    'run_id' : '6', # 
                    'eps': 2,
                    'delta': 1e-5,
                    'colour':colours[1],})

# 15 globals runs
"""
plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_1bnn_local_pvi_10clients_5seeds_eps2_runs/',
                    'fix_folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_1bnn_local_pvi_10clients_5seeds_eps2_fix_runs/',
                    'name' : 'virtual',
                    'run_id' : '45',
                    #'fix_ids' : ['1'],
                    'eps': 2,
                    'delta': 1e-5,
                    'colour':colours[2],})
#"""

#"""
plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_1bnn_local_pvi_10clients_5seeds_eps2_runs/',
                    'fix_folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_1bnn_local_pvi_10clients_5seeds_eps2_fix_runs/',
                    'name' : 'virtual',
                    'run_id' : '2',
                    'fix_ids' : ['1','3'],
                    'eps': 2,
                    'delta': 1e-5,
                    'colour':colours[2],})
#"""
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_1bnn_local_pvi_10clients_5seeds_eps2_runs/',
                    'fix_folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_1bnn_local_pvi_10clients_5seeds_eps2_fix2_runs/',
                    'name' : 'virtual',
                    'run_id' : '10', # 
                    'fix_ids' : ['4'],
                    'eps': 2,
                    'delta': 1e-5,
                    'colour':colours[2],})

plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_1bnn_local_pvi_10clients_5seeds_eps2_runs/',
                    'fix_folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_1bnn_local_pvi_10clients_5seeds_eps2_fix2_runs/',
                    'name' : 'virtual',
                    'run_id' : '9', # 
                    'fix_ids' : ['2','6'],
                    'eps': 2,
                    'delta': 1e-5,
                    'colour':colours[2],})


plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_1bnn_bcm_same_10clients_5seeds_eps2_runs/',
                    'name' : 'BCM same',
                    'run_id' : '2', # run number in main folder
                    'eps': 2,
                    'delta': 1e-5,
                    'colour':colours[3],})
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_1bnn_bcm_same_10clients_5seeds_eps2_runs/',
                    'name' : 'BCM same',
                    'run_id' : '1', #4,1
                    'eps': 2,
                    'delta': 1e-5,
                    'colour':colours[3],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_1bnn_bcm_same_10clients_5seeds_eps2_runs/',
                    'name' : 'BCM same',
                    'run_id' : '3', # 5,3
                    'eps': 2,
                    'delta': 1e-5,
                    'colour':colours[3],})



plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_1bnn_bcm_split_10clients_5seeds_eps2_runs/',
                    'name' : 'BCM split',
                    'run_id' : '4', # 1,4
                    'eps': 2,
                    'delta': 1e-5,
                    'colour':colours[4],})
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_1bnn_bcm_split_10clients_5seeds_eps2_runs/',
                    'name' : 'BCM split',
                    'run_id' : '8', #7,8
                    'eps': 2,
                    'delta': 1e-5,
                    'colour':colours[4],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_1bnn_bcm_split_10clients_5seeds_eps2_runs/',
                    'name' : 'BCM split',
                    'run_id' : '9',#10,9
                    'eps': 2,
                    'delta': 1e-5,
                    'colour':colours[4],})

# for global vi need to have 'clients' directly in dict
plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_1bnn_comms_baseline_5seeds_eps2_runs/',
                    'name' : 'global VI, trusted aggr.',
                    'clients' : 10,
                    'run_id' : '1', # run number in main folder
                    'eps': 2,
                    'delta': 1e-5,
                    'colour':colours[5],})
# full trusted aggr comms baseline same for all splits
plot_group_unbal1.append(plot_group_bal[-1])
plot_group_unbal2.append(plot_group_bal[-1])

# %% [markdown]
# ### Adult runs, 200 clients

# %%
#try adult 200clients: 
colours = plt.rcParams['axes.prop_cycle'].by_key()['color']

plot_group_bal = []
plot_group_unbal1 = []
plot_group_unbal2 = []

"""
plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_dpsgd_200clients_5seeds_eps03_runs/',
                    'name' : 'local optim',
                    'run_id' : '9',
                    'eps':.3,
                    'delta': 1e-5,
                    'colour':colours[0],})
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_dpsgd_200clients_5seeds_eps03_runs/',
                    'name' : 'local optim',
                    'run_id' : '8',
                    'eps':.3,
                    'delta': 1e-5,
                    'colour':colours[0],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_dpsgd_200clients_5seeds_eps03_runs/',
                    'name' : 'local optim',
                    'run_id' : '2',
                    'eps':.3,
                    'delta': 1e-5,
                    'colour':colours[0],})
"""
# dpsgd eps .5
plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_dpsgd_200clients_5seeds_eps05_runs/',
                    'name' : 'DP optimisation',
                    'run_id' : '7',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[0],})
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_dpsgd_200clients_5seeds_eps05_runs/',
                    'name' : 'DP optimisation',
                    'run_id' : '11',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[0],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_dpsgd_200clients_5seeds_eps05_runs/',
                    'name' : 'DP optimisation',
                    'run_id' : '13',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[0],})

"""
# lfa sec eps .3
plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_200clients_5seeds_eps03_sec_runs/',
                    'name' : 'local avg, trusted aggr.',
                    'run_id' : '3',
                    'eps':.3,
                    'delta': 1e-5,
                    'colour':colours[1],})
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_200clients_5seeds_eps03_sec_runs/',
                    'name' : 'local avg, trusted aggr.',
                    'run_id' : '14',
                    'eps':.3,
                    'delta': 1e-5,
                    'colour':colours[1],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_200clients_5seeds_eps03_sec_runs/',
                    'name' : 'local avg, trusted aggr.',
                    'run_id' : '12',
                    'eps':.3,
                    'delta': 1e-5,
                    'colour':colours[1],})
"""
# lfa sec eps .5
plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_200clients_5seeds_eps05_sec_runs/',
                    'name' : 'local avg, trusted aggr.',
                    'run_id' : '1',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[1],})
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_200clients_5seeds_eps05_sec_runs/',
                    'name' : 'local avg, trusted aggr.',
                    'run_id' : '9',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[1],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_lfa_200clients_5seeds_eps05_sec_runs/',
                    'name' : 'local avg, trusted aggr.',
                    'run_id' : '17',
                    'eps':.5,
                    'delta':1e-5,
                    'colour':colours[1],})


#######

# virtual clients sec eps .3
"""
plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_200clients_5seeds_eps03_sec_runs/',
                    'name' : 'virtual, trusted aggr.',
                    'run_id' : '?',
                    'eps':.3,
                    'delta': 1e-5,
                    'colour':colours[2],})
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_200clients_5seeds_eps03_sec_runs/',
                    'name' : 'virtual, trusted aggr.',
                    'run_id' : '7',
                    'eps':.3,
                    'delta': 1e-5,
                    'colour':colours[2],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_200clients_5seeds_eps03_sec_runs/',
                    'name' : 'virtual, trusted aggr.',
                    'run_id' : '8',
                    'eps':.3,
                    'delta': 1e-5,
                    'colour':colours[2],})
"""

# virtual clients sec eps .5
plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_200clients_5seeds_eps05_sec_runs/',
                    'name' : 'virtual, trusted aggr.',
                    'run_id' : '3',
                    'eps':.5,
                    'delta':1e-5,
                    'colour': colours[2],})
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_200clients_5seeds_eps05_sec_runs/',
                    'name' : 'virtual, trusted aggr.',
                    'run_id' : '13',
                    'eps':.5,
                    'delta':1e-5,
                    'colour': colours[2],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_local_pvi_200clients_5seeds_eps05_sec_runs/',
                    'name' : 'virtual, trusted aggr.',
                    'run_id' : '12',
                    'eps':.5,
                    'delta':1e-5,
                    'colour': colours[2],})

plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_bcm_same_200clients_5seeds_eps05_runs/',
                    'name' : 'BCM same',
                    'run_id' : '3', # 30,3
                    'eps': .5,
                    'delta': 1e-5,
                    'colour':colours[3],})
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_bcm_same_200clients_5seeds_eps05_runs/',
                    'name' : 'BCM same',
                    'run_id' : '2', # 2
                    'eps': .5,
                    'delta': 1e-5,
                    'colour':colours[3],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_bcm_same_200clients_5seeds_eps05_runs/',
                    'name' : 'BCM same',
                    'run_id' : '16', # 16
                    'eps': .5,
                    'delta': 1e-5,
                    'colour':colours[3],})



plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_bcm_split_200clients_5seeds_eps05_runs/',
                    'name' : 'BCM split',
                    'run_id' : '1', # 16,1
                    'eps': .5,
                    'delta': 1e-5,
                    'colour':colours[4],})
plot_group_unbal1.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_bcm_split_200clients_5seeds_eps05_runs/',
                    'name' : 'BCM split',
                    'run_id' : '2', # 4,2
                    'eps': .5,
                    'delta': 1e-5,
                    'colour':colours[4],})
plot_group_unbal2.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_bcm_split_200clients_5seeds_eps05_runs/',
                    'name' : 'BCM split',
                    'run_id' : '21', # 13,21
                    'eps': .5,
                    'delta': 1e-5,
                    'colour':colours[4],})


# for global vi need to have 'clients' directly in dict

plot_group_bal.append({ 'folder' : '/Users/mixheikk/Documents/git/DP-PVI/pytorch-code-results/adult_comms_baseline_5seeds_eps05_runs/',
                    'name' : 'global VI, trusted aggr.',
                    'clients' : 200,
                    'run_id' : '2', 
                    'eps': .5,
                    'delta': 1e-5,
                    'colour':colours[5],})
# full trusted aggr comms baseline same for all splits
plot_group_unbal1.append(plot_group_bal[-1])
plot_group_unbal2.append(plot_group_bal[-1])

# %%
# check that individual run is ok
#for k in all_res['validation_res']:
#    print(k)
#print(all_res['validation_res']['2']['logl'].shape)
#print(all_res['validation_res']['2']['logl'])
print( [np.any(np.isnan(all_res['validation_res']['2']['logl'][:,i_dim])) for i_dim in range(all_res['validation_res']['2']['logl'].shape[-1]) ])
# Out:
# [False, False, False, False, True]

# %% [markdown]
# ### Set this and run

# %%
# CHOOSE PLOT GROUP:
plot_group = plot_group_unbal2

# read results
all_res, all_baselines = reset_all_res()
#read_results_for_groups(all_res, plot_group, dataset_name='mimic')
read_results_for_groups(all_res, plot_group, dataset_name='adult')

# get some extra info for plotting from configs
for i_group, params in enumerate(plot_group):
    params['seeds'] = all_res['config'][str(i_group)]['n_rng_seeds']
    if 'bcm' in all_res['config'][str(i_group)]['model']:
        # bcm communications=1 per client
        params['x_step'] = 1 #all_res['config'][str(i_group)]['clients']
        params['x_len'] = 1
        # add small offset to distinguish error bars better
        #'''
        if 'same' in all_res['config'][str(i_group)]['model']:
            params['x_step'] += .05
        #'''
    elif 'global' in all_res['config'][str(i_group)]['model'] or 'global' in params['name']:
        # global vi via sec.aggr: n_global_updates * clients
        params['x_step'] = 1 #params['clients'] # NOTE: global_vi clients=1, so can't read directly from config
        params['x_len'] = all_res['config'][str(i_group)]['n_global_updates']
    else:
        # no difference in total comms between seq and synch: global update goes through all clients in both cases, difference is just in 
        if all_res['config'][str(i_group)]['server'] == 'synchronous':
            params['x_step'] = 1 #all_res['config'][str(i_group)]['clients']
            params['x_len'] = all_res['config'][str(i_group)]['n_global_updates']
        elif all_res['config'][str(i_group)]['server'] == 'sequential':
            params['x_step'] = 1
            params['x_len'] = all_res['config'][str(i_group)]['n_global_updates']
        else:
            print(f"Unknown server in group {i_group}: {all_res['config'][str(i_group)]['server']}!")
            print(f"Group name: {params['name']}")
# Out:
# run 13
# run 17
# run 12
# run 16
# run 21
# run 2

# %%
# plot 200 clients Adult balanced split
plot_figure(all_res, plot_group, suptitle='Log.regr. with Adult, 200 clients, balanced split', 
            measures=['acc','logl'], y_names=['Accuracy', 'Logl'], 
            markersize=12, ylims = ((.75,.86),(-.6,-.3)), 
            filename=None,
            #filename = 'figs/adult_200clients_comms_plot_bal.pdf',
            #filename = 'figs/adult_200clients_comms_plot_bal_no_legend.pdf',
            legend_font_size=14,
           )

# %%
# plot 200 clients Adult unbalanced1 split
plot_figure(all_res, plot_group, suptitle='Log.regr. with Adult, 200 clients, unbalanced split 1', 
            measures=['acc','logl'], y_names=['Accuracy', 'Logl'], 
            markersize=12, ylims = ((.75,.86),(-.6,-.3)), 
            filename=None,
            #filename = 'figs/adult_200clients_comms_plot_unbal1.pdf',
            #filename = 'figs/adult_200clients_comms_plot_unbal1_no_legend.pdf',
            legend_font_size=14,
           )

# %%
# plot 200 clients Adult unbalanced2 split
plot_figure(all_res, plot_group, suptitle='Log.regr. with Adult, 200 clients, unbalanced split 2', 
            measures=['acc','logl'], y_names=['Accuracy', 'Logl'], 
            markersize=12, ylims = ((.75,.86),(-.6,-.3)), 
            filename=None,
            #filename = 'figs/adult_200clients_comms_plot_unbal2.pdf',
            #filename = 'figs/adult_200clients_comms_plot_unbal2_no_legend.pdf',
            legend_font_size=14,
           )

# %%
#print(plot_group)

# %%
# plot 1BNN Adult balanced split
plot_figure(all_res, plot_group, suptitle='BNN with Adult, 10 clients, balanced split', 
            measures=['acc','logl'], y_names=['Accuracy', 'Logl'], 
            markersize=12, ylims = ((.75,.86),(-.6,-.3)), 
            filename=None,
            #filename = 'figs/adult_1bnn_10clients_comms_plot_eps2_bal.pdf',
            #filename = 'figs/adult_1bnn_10clients_comms_plot_eps2_bal_no_legend.pdf',
            legend_font_size=14,
           )

# %%
# plot 1BNN Adult unbalanced1 split
plot_figure(all_res, plot_group, suptitle='BNN with Adult, 10 clients, unbalanced split 1', 
            measures=['acc','logl'], y_names=['Accuracy', 'Logl'], 
            markersize=12, ylims = ((.75,.86),(-.6,-.3)), 
            filename=None,
            #filename = 'figs/adult_1bnn_10clients_comms_plot_eps2_unbal1.pdf',
            #filename = 'figs/adult_1bnn_10clients_comms_plot_eps2_unbal1_no_legend.pdf',
            legend_font_size=14,
           )

# %%
# plot 1BNN Adult unbalanced2 split
plot_figure(all_res, plot_group, suptitle='BNN with Adult, 10 clients, unbalanced split 2', 
            measures=['acc','logl'], y_names=['Accuracy', 'Logl'], 
            markersize=12, ylims = ((.75,.86),(-.6,-.3)), 
            filename=None,
            #filename = 'figs/adult_1bnn_10clients_comms_plot_eps2_unbal2.pdf',
            #filename = 'figs/adult_1bnn_10clients_comms_plot_eps2_unbal2_no_legend.pdf',
            legend_font_size=14,
           )

# %%
for k in all_res:
    print(k)
#print(all_res)
print(all_res['validation_res']['0']['best_acc'])
print(all_res['validation_res']['1']['best_acc'])

# %%
# plot Adult balanced split
plot_figure(all_res, plot_group, suptitle='Log.regr. with Adult, 10 clients, balanced split', 
            measures=['acc','logl'], y_names=['Accuracy', 'Logl'], 
            markersize=12, ylims = ((.75,.86),(-.6,-.3)), 
            filename=None,
            #filename = 'figs/adult_10clients_comms_plot_bal.pdf',
            #filename = 'figs/adult_10clients_comms_plot_bal_no_legend.pdf',
            legend_font_size=14,
           )

# %%
# plot Adult unbalanced split (.75,.95)
plot_figure(all_res, plot_group, suptitle='Log.regr. with Adult, 10 clients, unbalanced split 1', 
            measures=['acc','logl'], y_names=['Accuracy', 'Logl'], 
            markersize=12, ylims = ((.75,.86),(-.6,-.3)), 
            #filename=None,
            filename = 'figs/adult_10clients_comms_plot_unbal1.pdf',
            #filename = 'figs/adult_10clients_comms_plot_unbal1_no_legend.pdf',
            legend_font_size=14,
           )

# %%
# plot Adult unbalanced split (.7,-3.)
plot_figure(all_res, plot_group, suptitle='Log.regr. with Adult, 10 clients, unbalanced split 2', 
            measures=['acc','logl'], y_names=['Accuracy', 'Logl'], 
            markersize=12, ylims = ((.75,.86),(-.6,-.3)), 
            filename=None,
            #filename = 'figs/adult_10clients_comms_plot_unbal2.pdf',
            #filename = 'figs/adult_10clients_comms_plot_unbal2_no_legend.pdf',
            legend_font_size=14,
           )

# %%
# plot MIMIC balanced split
plot_figure(all_res, plot_group, suptitle='Log.regr. with balanced MIMIC-III, 10 clients, balanced split', 
            measures=['acc','logl'], y_names=['Accuracy', 'Logl'], 
            markersize=12, ylims = ((.5,.78),(-.7,-.5)), 
            filename=None,
            #filename = 'figs/mimic_bal_10clients_comms_plot_bal.pdf',
            #filename = 'figs/mimic_bal_10clients_comms_plot_bal_no_legend.pdf',
            legend_font_size=14,
           )

# %%
# plot MIMIC unbalanced split1
plot_figure(all_res, plot_group, 
            suptitle='Log.regr. with balanced MIMIC-III, 10 clients, unbalanced split 1', 
            measures=['acc','logl'], y_names=['Accuracy', 'Logl'], 
            markersize=12, ylims = ((.5,.78),(-.7,-.5)), 
            filename=None,
            #filename = 'figs/mimic_bal_10clients_comms_plot_unbal1.pdf',
            #filename = 'figs/mimic_bal_10clients_comms_plot_unbal1_no_legend.pdf',
            legend_font_size=14,
           )

# %%
# plot MIMIC unbalanced split2
plot_figure(all_res, plot_group, 
            suptitle='Log.regr. with balanced MIMIC-III, 10 clients, unbalanced split 2', 
            measures=['acc','logl'], y_names=['Accuracy', 'Logl'], 
            markersize=12, ylims = ((.5,.78),(-.7,-.5)), 
            filename=None,
            #filename = 'figs/mimic_bal_10clients_comms_plot_unbal2.pdf',
            #filename = 'figs/mimic_bal_10clients_comms_plot_unbal2_no_legend.pdf',
            legend_font_size=14,
           )

# %% [markdown]
# Figure 1 is too crowded, and the font size is too small.
# Could consider having a common legend (instead of one per subplot),
# with _significantly_ larger font size.
# Additionally, there are too many methods on the left of the plot that overlap in a small area.
# Perhaps could have 2 subplots per row (hence stretching out the x-axis, but also adding a couple more rows)?

# %%
def plot_only_legend(all_res, plot_group, suptitle='', measures=['acc','logl'], y_names=['Accuracy', 'Logl'], markersize=12, ylims=None, filename=None, legend_font_size=14, linewidth=2):
    fig, axs = plt.subplots(1,1, figsize=(8,10))
    for i_method, params in enumerate(plot_group):
        x = 1
        y = 1
        yerr = None    
        if 'BCM' in params['name']:
            axs.errorbar(None,None,
                        yerr=yerr,
                        marker='*', markersize=markersize,
                        linewidth=0,
                        linestyle = None,
                        label=params['name'],
                        color=params['colour'])
        else:
            if 'global' in params['name'] or 'trusted' in params['name']:
                ls = '--'
            else:
                ls = '-'
            axs.plot(x, y, label=params['name'],linestyle=ls, linewidth=linewidth, color=params['colour'])
    axs.legend(loc=10, fontsize=legend_font_size, framealpha=1., mode='expand')
    axs.set_axis_off()
    plt.tight_layout()
    if filename is None:
        plt.show()
    else:
        plt.savefig(filename)

# %%
# plot legend only
plot_only_legend(all_res, plot_group, suptitle='Log.regr. with Adult, 10 clients, balanced split', 
            measures=['acc','logl'], y_names=['Accuracy', 'Logl'], 
            markersize=24, ylims = ((.75,.86),(-.6,-.3)), 
            filename=None,
            #filename = 'figs/legend.pdf',
            #filename = 'figs/BNN_legend.pdf',
            #filename = 'figs/200adult_legend.pdf',
            legend_font_size=34,
            linewidth = 8,
           )

# %%
import copy
# read results
def read_results_for_groups(all_res, plot_groups, dataset_name='adult'):
    for i_group, params in enumerate(plot_group):
        get_results(all_res, plot_id=str(i_group), run_id=params['run_id'], main_folder=params['folder'], dataset_name=dataset_name)
        # check for missing runs to replace
        to_replace = [np.any(np.isnan(all_res['validation_res'][str(i_group)]['logl'][:,i_dim])) for i_dim in range(all_res['validation_res'][str(i_group)]['logl'].shape[-1]) ]
        #print( [np.any(np.isnan(all_res['validation_res'][str(i_group)]['logl'][:,i_dim])) for i_dim in range(all_res['validation_res']['2']['logl'].shape[-1]) ])
        #print(to_replace)
        if np.any(to_replace):
            print(f'replacing {np.sum(to_replace)} diverged runs')
            #print(params['fix_folder'])
            #print(params['fix_ids'])
            replaced = 0
            for i_replace,replace in enumerate(to_replace):
                if not replace:
                    continue
                print(f'replacing {replaced} at {i_replace}')
                replace_num = params['fix_ids'][replaced]
                filename_bck = params['fix_folder'] + replace_num + '/info_bck.json'
                apu = read_results('', filename_bck)

                #print(apu['validation_res_seed0']['logl'].shape)
                #print(all_res['config'])
                #print(f'apu: \n{apu}')
                #sys.exit()
                # format results for plotting
                client_measures = ['elbo','kl','logl']
                tmp_res = OD()
                tmp_res['config'] = {} 
                tmp_res['config'][str(i_group)] = copy.deepcopy(all_res['config'][str(i_group)])
                #for k in tmp_res['config']['2']:
                #    print(k)
                tmp_res['config'][str(i_group)]['n_rng_seeds'] = 1
                tmp_res['validation_res'] = OD()
                
                #print(to_replace)
                #print(all_res['config'][str(i_group)])
                #sys.exit()
                #print(f'i_group: {i_group}')
                format_results(apu, str(i_group), client_measures, tmp_res, dataset_name='adult')
                #print(tmp_res)

                #sys.exit()
                for k in all_res['validation_res'][str(i_group)]:
                    if 'TPR' in k or 'TNR' in k or 'best' in k or 'ROC' in k:
                        continue
                    #print(k)
                    #print( all_res['validation_res'][str(i_group)][k].shape)
                    #print(f"shape: {all_res['validation_res'][str(i_group)][k][:,i_replace].shape}, {tmp_res['validation_res'][str(i_group)][k].reshape(-1).shape}")
                    all_res['validation_res'][str(i_group)][k][:,i_replace] = tmp_res['validation_res'][str(i_group)][k].reshape(-1)
                    

                replaced += 1
    
            #sys.exit()


# define helper funs
def plot_figure(all_res, plot_group, suptitle='', measures=['acc','logl'], y_names=['Accuracy', 'Logl'], markersize=12, ylims=None, filename=None, legend_font_size=14, plot_legend=False):
    fig, axs = plt.subplots(2,1, figsize=(8,10))
    for i_method, params in enumerate(plot_group):
        for i in range(2):
            assert not np.any( np.isnan(all_res['validation_res'][str(i_method)][measures[i]]))
            if 'BCM' in params['name']:
                x = params['x_step']
                y = all_res['validation_res'][str(i_method)][measures[i]].mean(-1)
                yerr = 2*all_res['validation_res'][str(i_method)][measures[i]].std(-1)/np.sqrt(params['seeds'])
                axs[i].errorbar(x,y,
                        yerr=yerr,
                        marker='*', markersize=markersize,
                        linewidth=0,
                        label=params['name'],
                        color=params['colour'])
            else:
                if 'global' in params['name'] or 'trusted' in params['name']:
                    ls = '--'
                else:
                    ls = '-'
                x = np.linspace(1,params['x_step']*params['x_len'], params['x_step']*params['x_len'])
                y = all_res['validation_res'][str(i_method)][measures[i]].mean(-1).repeat(params['x_step'])
                yerr = 1*all_res['validation_res'][str(i_method)][measures[i]].std(-1).repeat(params['x_step'])/np.sqrt(params['seeds'])
                #axs[i].errorbar(x, y,
                #            yerr=yerr,
                #            label=params['name'],
                #           )
                #print(x.shape,y.shape,yerr.shape)
                axs[i].plot(x, y, label=params['name'],linestyle=ls, color=params['colour'])
                axs[i].fill_between(x, y-yerr, y+yerr, alpha=.1, antialiased=1, color=params['colour'])

    for i in range(2):
        axs[i].set_xscale('log')
        axs[i].grid()
        #axs[i].legend(loc=4, prop={'size': legend_font_size})
        if plot_legend:
            axs[i].legend(loc=4, fontsize=legend_font_size)
        axs[i].set_xlabel('Communications', fontsize=legend_font_size+1)
        if ylims is not None:
            axs[i].set_ylim(ylims[i])
        axs[i].set_ylabel(y_names[i], fontsize=legend_font_size+1)
    plt.suptitle(suptitle, fontsize=legend_font_size+2)
    plt.tight_layout()
    if filename is None:
        plt.show()
    else:
        plt.savefig(filename)

#

def reset_all_res():
    all_res = OD()
    all_res['config'] = OD()
    all_res['validation_res'] = OD()
    all_baselines = OD()
    all_baselines['config'] = OD()
    all_baselines['validation_res'] = OD()
    return all_res, all_baselines

def get_results(all_res,plot_id,run_id, main_folder, dataset_name):
    """ run_id (str): run id in main folder
        plot_id (str): id for plotting
    """
    print(f'run {run_id}')
    filename = main_folder + run_id + '/config.json'
    #print(f'trying {filename}')
    tmp = read_config(filename, failed_runs=[])
    #if i_run in failed_runs:
    #    continue
    all_res['config'][plot_id] = tmp[0]

    # try opening sacred records, if missing open manual bck instead
    #filename = main_folder + run_id + '/info.json'
    filename = ''
    filename_bck = main_folder + run_id + '/info_bck.json'
    apu = read_results(filename, filename_bck)

    #print(apu['validation_res_seed0']['logl'].shape)
    #sys.exit()

    #for k in apu:
    #    print(k)
    #sys.exit()
    
    # format results for plotting
    client_measures = ['elbo','kl','logl']
    format_results(apu, plot_id, client_measures, all_res, dataset_name)

#
def read_config(filename, failed_runs):
    try:
        with open(filename, 'r') as f:
            apu = f.read()
    except FileNotFoundError as err:
        print(f"Can't open file {filename}! Skipping")
        failed_runs.append(i_run)
        return None
    apu = jsonpickle.unpickler.decode(apu)
    #print(apu)
    return apu, failed_runs


def read_results(filename, filename_bck):
    try:
        with open(filename, 'r') as f:
            apu = f.read()
        try:
            apu = jsonpickle.unpickler.decode(apu)
        except:
            print(f'error in JSON decoding in run {filename}')
            with open(filename, 'r') as f:
                apu = f.read()
            print('results from file: {}\n{}'.format(filename,apu))
            sys.exit()
    except FileNotFoundError as err:
        import json
        with open(filename_bck, 'r') as f:
            apu = f.read()
            apu = json.loads(apu)
        try:
            #apu = jsonpickle.unpickler.decode(apu)
            #print(apu)
            apu = jsonpickle.decode(apu, keys=True)
            #print(apu)
            #print('at bck decode')
        except:
            print(f'error in JSON decoding in {filename_bck}')
            #with open(filename, 'r') as f:
            #    apu = f.read()
            #print('results from file: {}\n{}'.format(filename,apu))
            sys.exit()
    return apu

def format_results(apu, run_id, client_measures, all_res, dataset_name):

    '''
    all_res['client_train_res'][run_id] = {}

    for k in client_measures:
        all_res['client_train_res'][run_id][k] = np.zeros((
            all_res['config'][run_id]['clients'],  
            all_res['config'][run_id]['n_global_updates'],  
            all_res['config'][run_id]['n_steps'],  
            all_res['config'][run_id]['n_rng_seeds']
            ))
    '''
    measures = ['acc','logl']
    posneg_measures = ['avg_prec_score','balanced_acc','f1_score']
    
    #all_res['train_res'][run_id] = {}
    all_res['validation_res'][run_id] = {}
    for k in (measures+posneg_measures):
        #all_res['train_res'][run_id][k] = np.zeros((
        #    all_res['config'][run_id]['n_global_updates'],  
        #    all_res['config'][run_id]['n_rng_seeds']
        #    ))
        all_res['validation_res'][run_id][k] = np.zeros((
            all_res['config'][run_id]['n_global_updates'],  
            all_res['config'][run_id]['n_rng_seeds']
            ))
        #all_res['train_res'][run_id]['best_'+k] = np.zeros((
        #    all_res['config'][run_id]['n_rng_seeds']
        #    ))
        all_res['validation_res'][run_id]['best_'+k] = np.zeros((
            all_res['config'][run_id]['n_rng_seeds']
            ))

    # does this work with sampling=seq?
    if dataset_name != 'mnist' and apu['validation_res_seed0']['posneg'][0] is not None:
        # for plotting ROC curve for max logl global update, one for each seed
        all_res['validation_res'][run_id]['TPR'] = np.zeros((
            all_res['config'][run_id]['n_rng_seeds'],
            apu['validation_res_seed0']['posneg'][0]['n_points']
            ))
        all_res['validation_res'][run_id]['TNR'] = np.zeros((
            all_res['config'][run_id]['n_rng_seeds'],
            apu['validation_res_seed0']['posneg'][0]['n_points']
            ))
        all_res['validation_res'][run_id]['ROC_thresholds'] = np.linspace(0,1,apu['validation_res_seed0']['posneg'][0]['n_points'])


    for i_seed in range(all_res['config'][run_id]['n_rng_seeds']):
        # logl, elbo, kl
        '''
        if i_seed == 0:
            for k in apu[f'validation_res_seed{i_seed}']:
                print(k)
            print(apu[f'validation_res_seed{i_seed}']['acc'].shape )
            print(apu[f'client_train_res_seed{i_seed}']['logl'].shape )
        #'''
        #sys.exit()
        #for k in client_measures:
        #    try:
        #        all_res['client_train_res'][run_id][k][:,:,:,i_seed] = apu[f'client_train_res_seed{i_seed}'][k]
        #    except KeyError as err:
        #        print(f'KeyError in run {i_run} (=folder)')
        #        print(f'got\n{apu}')
        #        print("config: batch_size={}, jobid={}".format(all_res['config'][run_id]['batch_size'], all_res['config'][run_id]['job_id'] ))
        #        raise err

        for k in measures:
            #all_res['train_res'][run_id][k][:,i_seed] = apu[f'train_res_seed{i_seed}'][k]
            all_res['validation_res'][run_id][k][:,i_seed] = apu[f'validation_res_seed{i_seed}'][k]

            #all_res['train_res'][run_id]['best_'+k][i_seed] = np.amax(all_res['train_res'][run_id][k][:,i_seed])
            all_res['validation_res'][run_id]['best_'+k][i_seed] = np.amax(all_res['validation_res'][run_id][k][:,i_seed])

        # calculate true positive and true negative rates at global update with best logl
        #print( all_res['validation_res'][run_id]['logl'][:,i_seed] )
        best_global_logl = np.argmax( all_res['validation_res'][run_id]['logl'][:,i_seed] )
        #print(all_res['validation_res'][run_id]['logl'][:,i_seed][best_global_logl])
        #print(all_res['validation_res'][run_id]['best_logl'][i_seed])
        # all_res['validation_res'][run_id] = {}
        #sys.exit()

        if dataset_name != 'mnist' and apu['validation_res_seed0']['posneg'][0] is not None:
            try:
                all_res['validation_res'][run_id]['TPR'][i_seed,:] = apu[f"validation_res_seed{i_seed}"]['posneg'][best_global_logl]['TP']/( apu[f"validation_res_seed{i_seed}"]['posneg'][best_global_logl]['TP'] + apu[f"validation_res_seed{i_seed}"]['posneg'][best_global_logl]['FN'])

                all_res['validation_res'][run_id]['TNR'][i_seed,:] = apu[f"validation_res_seed{i_seed}"]['posneg'][best_global_logl]['TN']/( apu[f"validation_res_seed{i_seed}"]['posneg'][best_global_logl]['TN'] + apu[f"validation_res_seed{i_seed}"]['posneg'][best_global_logl]['FP'])
                # posneg = list of posneg dicts with len=n_global_updates
                # NOTE: need to check format when n_seeds > 1
                for i_global in range(all_res['config'][run_id]['n_global_updates']):
                    for k in posneg_measures:
                        #print(apu[f"validation_res_seed0"]['posneg'][i_global][k])
                        #all_res['train_res'][run_id][k][i_global,i_seed] = apu[f"train_res_seed{i_seed}"]['posneg'][i_global][k]
                        all_res['validation_res'][run_id][k][i_global,i_seed] = apu[f"validation_res_seed{i_seed}"]['posneg'][i_global][k]
                        #print(len(apu[f"validation_res_seed0"]['posneg']),len(apu[f"train_res_seed0"]['posneg'] ))
                        #sys.exit()

                for k in posneg_measures:
                    #all_res['train_res'][run_id]['best_'+k][i_seed] = np.amax(all_res['train_res'][run_id][k][:,i_seed])
                    all_res['validation_res'][run_id]['best_'+k][i_seed] = np.amax(all_res['validation_res'][run_id][k][:,i_seed])
            except:
                pass
